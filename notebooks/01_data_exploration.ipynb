# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
art_daily_no_noise = pd.read_csv("../data/artificialNoAnomaly/art_daily_no_noise.csv")
art_daily_no_noise
# Out:
#                 timestamp     value
# 0     2014-04-01 00:00:00  20.00000
# 1     2014-04-01 00:05:00  20.00000
# 2     2014-04-01 00:10:00  20.00000
# 3     2014-04-01 00:15:00  20.00000
# 4     2014-04-01 00:20:00  20.00000
# ...                   ...       ...
# 4027  2014-04-14 23:35:00  20.00384
# 4028  2014-04-14 23:40:00  20.00384
# 4029  2014-04-14 23:45:00  20.00384
# 4030  2014-04-14 23:50:00  20.00384
# 4031  2014-04-14 23:55:00  20.00384
#
# [4032 rows x 2 columns]

# %%
art_daily_no_noise.isnull().sum()
# Out:
# timestamp    0
# value        0
# dtype: int64

# %%
art_daily_no_noise["value"].min()
# Out:
# np.float64(20.0)

# %%
art_daily_no_noise["value"].max()
# Out:
# np.float64(79.99996928)

# %%
sns.lineplot(art_daily_no_noise, x = "timestamp", y = "value")
# Out:
# <Axes: xlabel='timestamp', ylabel='value'>

# %% [raw]
# Observations:
#
# The patterns looks smooth and similar throughout the timestamp
# No sudden changes detected

# %% [raw]
# We can say that the dataset represents normal system behaviour with predictable patterns
# and no anomalies. An ideal learning behaviour and training models to understand what normal looks like

# %% [raw]
# Knowing the normal pattern at each time interval helps the system avoid raising alerts for expected behaviour

# %%
art_daily_perfect_square = pd.read_csv("../data/artificialNoAnomaly/art_daily_perfect_square_wave.csv")
art_daily_perfect_square
# Out:
#                 timestamp  value
# 0     2014-04-01 00:00:00   20.0
# 1     2014-04-01 00:05:00   20.0
# 2     2014-04-01 00:10:00   20.0
# 3     2014-04-01 00:15:00   20.0
# 4     2014-04-01 00:20:00   20.0
# ...                   ...    ...
# 4027  2014-04-14 23:35:00   20.0
# 4028  2014-04-14 23:40:00   20.0
# 4029  2014-04-14 23:45:00   20.0
# 4030  2014-04-14 23:50:00   20.0
# 4031  2014-04-14 23:55:00   20.0
#
# [4032 rows x 2 columns]

# %%
sns.lineplot(art_daily_perfect_square, x = "timestamp", y="value")
# Out:
# <Axes: xlabel='timestamp', ylabel='value'>

# %% [raw]
# Observation:
#
# This metric shows a repeating pattern with consistant amplitude, representing predictable periodic system behaviour

# %%
art_daily_small_noise = pd.read_csv("../data/artificialNoAnomaly/art_daily_small_noise.csv")
art_daily_small_noise
# Out:
#                 timestamp      value
# 0     2014-04-01 00:00:00  18.324919
# 1     2014-04-01 00:05:00  21.970327
# 2     2014-04-01 00:10:00  18.624806
# 3     2014-04-01 00:15:00  21.953684
# 4     2014-04-01 00:20:00  21.909120
# ...                   ...        ...
# 4027  2014-04-14 23:35:00  20.211195
# 4028  2014-04-14 23:40:00  20.531041
# 4029  2014-04-14 23:45:00  19.032127
# 4030  2014-04-14 23:50:00  21.798801
# 4031  2014-04-14 23:55:00  18.682620
#
# [4032 rows x 2 columns]

# %%
sns.lineplot(art_daily_small_noise, x = "timestamp", y ="value")
# Out:
# <Axes: xlabel='timestamp', ylabel='value'>

# %% [raw]
# Observation:
#
# There are minor fluctuations around a stable pattern but these represent normal behaviour with low level noise

# %%
art_flatline = pd.read_csv("../data/artificialNoAnomaly/art_flatline.csv")
art_flatline
# Out:
#                 timestamp  value
# 0     2014-04-01 00:00:00   45.0
# 1     2014-04-01 00:05:00   45.0
# 2     2014-04-01 00:10:00   45.0
# 3     2014-04-01 00:15:00   45.0
# 4     2014-04-01 00:20:00   45.0
# ...                   ...    ...
# 4027  2014-04-14 23:35:00   45.0
# 4028  2014-04-14 23:40:00   45.0
# 4029  2014-04-14 23:45:00   45.0
# 4030  2014-04-14 23:50:00   45.0
# 4031  2014-04-14 23:55:00   45.0
#
# [4032 rows x 2 columns]

# %%
sns.lineplot(art_flatline, x = "timestamp", y = "value")
# Out:
# <Axes: xlabel='timestamp', ylabel='value'>

# %% [raw]
# Observation:
#
# This metric remains consistant overtime, indicating stable idle system

# %%
art_noisy = pd.read_csv("../data/artificialNoAnomaly/art_noisy.csv")
art_noisy
# Out:
#                 timestamp      value
# 0     2014-04-01 00:00:00  18.622185
# 1     2014-04-01 00:05:00   8.163417
# 2     2014-04-01 00:10:00  13.292383
# 3     2014-04-01 00:15:00  11.667046
# 4     2014-04-01 00:20:00  12.940358
# ...                   ...        ...
# 4027  2014-04-14 23:35:00  10.689582
# 4028  2014-04-14 23:40:00   9.507657
# 4029  2014-04-14 23:45:00  17.339780
# 4030  2014-04-14 23:50:00  14.781273
# 4031  2014-04-14 23:55:00  10.051621
#
# [4032 rows x 2 columns]

# %%
sns.lineplot(art_noisy, x = "timestamp", y = "value")
# Out:
# <Axes: xlabel='timestamp', ylabel='value'>

# %% [raw]
# Observation:
#
# Despite showing noise and a recurring daily pattern it exihibits noise system behaviour

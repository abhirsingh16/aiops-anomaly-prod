# %%
import pandas as pd
import seaborn as sns

# %%
art_daily_flatmiddle = pd.read_csv("../data/artificialWithAnomaly/art_daily_flatmiddle.csv")
art_daily_flatmiddle
# Out:
#                 timestamp      value
# 0     2014-04-01 00:00:00 -21.048383
# 1     2014-04-01 00:05:00 -20.295477
# 2     2014-04-01 00:10:00 -18.127229
# 3     2014-04-01 00:15:00 -20.171665
# 4     2014-04-01 00:20:00 -21.223762
# ...                   ...        ...
# 4027  2014-04-14 23:35:00 -18.083562
# 4028  2014-04-14 23:40:00 -20.278406
# 4029  2014-04-14 23:45:00 -20.063239
# 4030  2014-04-14 23:50:00 -20.751973
# 4031  2014-04-14 23:55:00 -20.592696
#
# [4032 rows x 2 columns]

# %%
sns.lineplot(art_daily_flatmiddle, x = "timestamp", y = "value")
# Out:
# <Axes: xlabel='timestamp', ylabel='value'>

# %% [raw]
# observation:
#
# Largly the metric follows similar pattern but there is a sudden drop that breaks the expected behaviour.
# The anomaly appears to be point based rather than persistant as observed in the graph.

# %%
art_daily_jumpsdown = pd.read_csv("../data/artificialWithAnomaly/art_daily_jumpsdown.csv")
art_daily_jumpsdown
# Out:
#                 timestamp      value
# 0     2014-04-01 00:00:00  18.090486
# 1     2014-04-01 00:05:00  20.359843
# 2     2014-04-01 00:10:00  21.105470
# 3     2014-04-01 00:15:00  21.151585
# 4     2014-04-01 00:20:00  18.137141
# ...                   ...        ...
# 4027  2014-04-14 23:35:00  18.269290
# 4028  2014-04-14 23:40:00  19.087351
# 4029  2014-04-14 23:45:00  19.594689
# 4030  2014-04-14 23:50:00  19.767817
# 4031  2014-04-14 23:55:00  20.479156
#
# [4032 rows x 2 columns]

# %%
sns.lineplot(art_daily_jumpsdown, x = "timestamp", y = "value")
# Out:
# <Axes: xlabel='timestamp', ylabel='value'>

# %% [raw]
# Observation:
#
# There is a point anomaly, typlically a metric glitch or service interruption

# %%
art_daily_jumpsup = pd.read_csv("../data/artificialWithAnomaly/art_daily_jumpsup.csv")
art_daily_jumpsup
# Out:
#                 timestamp      value
# 0     2014-04-01 00:00:00  19.761252
# 1     2014-04-01 00:05:00  20.500833
# 2     2014-04-01 00:10:00  19.961641
# 3     2014-04-01 00:15:00  21.490266
# 4     2014-04-01 00:20:00  20.187739
# ...                   ...        ...
# 4027  2014-04-14 23:35:00  18.074649
# 4028  2014-04-14 23:40:00  21.002014
# 4029  2014-04-14 23:45:00  20.566713
# 4030  2014-04-14 23:50:00  18.254193
# 4031  2014-04-14 23:55:00  21.863147
#
# [4032 rows x 2 columns]

# %%
sns.lineplot(art_daily_jumpsup, x = "timestamp", y="value")
# Out:
# <Axes: xlabel='timestamp', ylabel='value'>

# %% [raw]
# Observation:
#
# There is an point spike anomaly typically due to heave traffic burst

# %%
art_daily_nojump = pd.read_csv("../data/artificialWithAnomaly/art_daily_nojump.csv")
art_daily_nojump
# Out:
#                 timestamp      value
# 0     2014-04-01 00:00:00  21.598011
# 1     2014-04-01 00:05:00  19.321392
# 2     2014-04-01 00:10:00  21.399938
# 3     2014-04-01 00:15:00  18.373916
# 4     2014-04-01 00:20:00  18.167499
# ...                   ...        ...
# 4027  2014-04-14 23:35:00  18.379705
# 4028  2014-04-14 23:40:00  19.383839
# 4029  2014-04-14 23:45:00  21.423756
# 4030  2014-04-14 23:50:00  21.851140
# 4031  2014-04-14 23:55:00  18.969085
#
# [4032 rows x 2 columns]

# %%
sns.lineplot(art_daily_nojump, x = "timestamp", y = "value")
# Out:
# <Axes: xlabel='timestamp', ylabel='value'>

# %% [raw]
# Observation :
#
# There is a distribution change/behaviorial change, the base noise level changes subtly

# %%
art_increase_spike_density = pd.read_csv("../data/artificialWithAnomaly/art_increase_spike_density.csv")
art_increase_spike_density
# Out:
#                 timestamp  value
# 0     2014-04-01 00:00:00   20.0
# 1     2014-04-01 00:05:00    0.0
# 2     2014-04-01 00:10:00    0.0
# 3     2014-04-01 00:15:00    0.0
# 4     2014-04-01 00:20:00    0.0
# ...                   ...    ...
# 4027  2014-04-14 23:35:00    0.0
# 4028  2014-04-14 23:40:00    0.0
# 4029  2014-04-14 23:45:00    0.0
# 4030  2014-04-14 23:50:00    0.0
# 4031  2014-04-14 23:55:00    0.0
#
# [4032 rows x 2 columns]

# %%
sns.lineplot(art_increase_spike_density, x = "timestamp", y = "value")
# Out:
# <Axes: xlabel='timestamp', ylabel='value'>

# %% [raw]
# Observation:
#
# The frequency of spikes increases

# %%
art_load_balancer_spikes = pd.read_csv("../data/artificialWithAnomaly/art_load_balancer_spikes.csv")
art_load_balancer_spikes
# Out:
#                 timestamp     value
# 0     2014-04-01 00:00:00  0.000000
# 1     2014-04-01 00:05:00  0.000000
# 2     2014-04-01 00:10:00  0.000000
# 3     2014-04-01 00:15:00  0.000000
# 4     2014-04-01 00:20:00  0.000000
# ...                   ...       ...
# 4027  2014-04-14 23:35:00  0.460912
# 4028  2014-04-14 23:40:00  0.472003
# 4029  2014-04-14 23:45:00  0.000000
# 4030  2014-04-14 23:50:00  0.000000
# 4031  2014-04-14 23:55:00  0.000000
#
# [4032 rows x 2 columns]

# %%
sns.lineplot(art_load_balancer_spikes, x = "timestamp", y="value")
# Out:
# <Axes: xlabel='timestamp', ylabel='value'>

# %% [raw]
# Observation:
#
# The patterns represnt noise system
